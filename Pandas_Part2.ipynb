# %%
import pandas as pd

# %%
cars = pd.read_csv("cars.csv")
cars
# Out:
#       Make                     Model   Type  Origin DriveTrain   MSRP  \
# 0    Acura                       MDX    SUV    Asia        All  36945
# 1    Acura            RSX Type S 2dr  Sedan    Asia      Front  23820
# 2    Acura                   TSX 4dr  Sedan    Asia      Front  26990
# 3    Acura                    TL 4dr  Sedan    Asia      Front  33195
# 4    Acura                3.5 RL 4dr  Sedan    Asia      Front  43755
# ..     ...                       ...    ...     ...        ...    ...
# 423  Volvo   C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 424  Volvo   C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 425  Volvo                S80 T6 4dr  Sedan  Europe      Front  45210
# 426  Volvo                       V40  Wagon  Europe      Front  26135
# 427  Volvo                      XC70  Wagon  Europe        All  35145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars.describe()
# Out:
#                 MSRP        Invoice  EngineSize   Cylinders  Horsepower  \
# count     428.000000     428.000000  428.000000  426.000000  428.000000
# mean    32774.855140   30014.700935    3.196729    5.807512  215.885514
# std     19431.716674   17642.117750    1.108595    1.558443   71.836032
# min     10280.000000    9875.000000    1.300000    3.000000   73.000000
# 25%     20334.250000   18866.000000    2.375000    4.000000  165.000000
# 50%     27635.000000   25294.500000    3.000000    6.000000  210.000000
# 75%     39205.000000   35710.250000    3.900000    6.000000  255.000000
# max    192465.000000  173560.000000    8.300000   12.000000  500.000000
#
#          MPG_City  MPG_Highway       Weight   Wheelbase      Length
# count  428.000000   428.000000   428.000000  428.000000  428.000000
# mean    20.060748    26.843458  3577.953271  108.154206  186.362150
# std      5.238218     5.741201   758.983215    8.311813   14.357991
# ...

# %%
cars.groupby("Make").count()
# Out:
#                Model  Type  Origin  DriveTrain  MSRP  Invoice  EngineSize  \
# Make
# Acura              7     7       7           7     7        7           7
# Audi              19    19      19          19    19       19          19
# BMW               20    20      20          20    20       20          20
# Buick              9     9       9           9     9        9           9
# Cadillac           8     8       8           8     8        8           8
# Chevrolet         27    27      27          27    27       27          27
# Chrysler          15    15      15          15    15       15          15
# Dodge             13    13      13          13    13       13          13
# Ford              23    23      23          23    23       23          23
# GMC                8     8       8           8     8        8           8
# Honda             17    17      17          17    17       17          17
# Hummer             1     1       1           1     1        1           1
# ...

# %%
cars.sort_values( ["Horsepower"], ascending = False)
# Out:
#               Make                                    Model    Type  Origin  \
# 114          Dodge             Viper SRT-10 convertible 2dr  Sports     USA
# 262  Mercedes-Benz                                CL600 2dr   Sedan  Europe
# 271  Mercedes-Benz                    SL600 convertible 2dr  Sports  Europe
# 270  Mercedes-Benz                             SL55 AMG 2dr  Sports  Europe
# 334        Porsche                              911 GT2 2dr  Sports  Europe
# ..             ...                                      ...     ...     ...
# 170        Hyundai                      Accent GT 2dr hatch   Sedan    Asia
# 67       Chevrolet                                 Aveo 4dr   Sedan     USA
# 404     Volkswagen                        Jetta GLS TDI 4dr   Sedan  Europe
# 149          Honda   Civic Hybrid 4dr manual (gas/electric)  Hybrid    Asia
# 150          Honda               Insight 2dr (gas/electric)  Hybrid    Asia
#
# ...

# %%
cars
# Out:
#       Make                     Model   Type  Origin DriveTrain   MSRP  \
# 0    Acura                       MDX    SUV    Asia        All  36945
# 1    Acura            RSX Type S 2dr  Sedan    Asia      Front  23820
# 2    Acura                   TSX 4dr  Sedan    Asia      Front  26990
# 3    Acura                    TL 4dr  Sedan    Asia      Front  33195
# 4    Acura                3.5 RL 4dr  Sedan    Asia      Front  43755
# ..     ...                       ...    ...     ...        ...    ...
# 423  Volvo   C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 424  Volvo   C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 425  Volvo                S80 T6 4dr  Sedan  Europe      Front  45210
# 426  Volvo                       V40  Wagon  Europe      Front  26135
# 427  Volvo                      XC70  Wagon  Europe        All  35145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    int64
#  6   Invoice      428 non-null    int64
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    int64
#  10  MPG_City     428 non-null    int64
#  11  MPG_Highway  428 non-null    int64
#  12  Weight       428 non-null    int64
#  13  Wheelbase    428 non-null    int64
#  14  Length       428 non-null    int64
# dtypes: float64(2), int64(8), object(5)
# memory usage: 50.3+ KB

# %%
cars.isna().any()
# Out:
# Make           False
# Model          False
# Type           False
# Origin         False
# DriveTrain     False
# MSRP           False
# Invoice        False
# EngineSize     False
# Cylinders       True
# Horsepower     False
# MPG_City       False
# MPG_Highway    False
# Weight         False
# Wheelbase      False
# Length         False
# dtype: bool

# %%
cars.isna().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
cars.loc[ cars.Cylinders.isna(), : ]
# Out:
#       Make                Model    Type Origin DriveTrain   MSRP  Invoice  \
# 247  Mazda   RX-8 4dr automatic  Sports   Asia       Rear  25700    23794
# 248  Mazda      RX-8 4dr manual  Sports   Asia       Rear  27200    25179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 247         1.3        NaN         197        18           25    3053
# 248         1.3        NaN         238        18           24    3029
#
#      Wheelbase  Length
# 247        106     174
# 248        106     174

# %%
cars.loc[ cars["Cylinders"].isna(), :  ]
# Out:
#       Make                Model    Type Origin DriveTrain   MSRP  Invoice  \
# 247  Mazda   RX-8 4dr automatic  Sports   Asia       Rear  25700    23794
# 248  Mazda      RX-8 4dr manual  Sports   Asia       Rear  27200    25179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 247         1.3        NaN         197        18           25    3053
# 248         1.3        NaN         238        18           24    3029
#
#      Wheelbase  Length
# 247        106     174
# 248        106     174

# %%
cars.Cylinders.fillna(6,inplace=True)

# %%
cars.loc[ cars["Cylinders"].isna(), :  ]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Type, Origin, DriveTrain, MSRP, Invoice, EngineSize, Cylinders, Horsepower, MPG_City, MPG_Highway, Weight, Wheelbase, Length]
# Index: []

# %%
cars
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/62/1yjqp2vn56jdb051vqfk6y2h0000gn/T/ipykernel_9290/3120145816.py in <module>
# ----> 1 cars
#
# NameError: name 'cars' is not defined

# %%
titanic = pd.read_excel("titanic.xls")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.isna().any()
# Out:
# pclass       False
# survived     False
# name         False
# sex          False
# age           True
# sibsp        False
# parch        False
# ticket       False
# fare          True
# cabin         True
# embarked      True
# boat          True
# body          True
# home.dest     True
# dtype: bool

# %%
titanic.isna().any()[titanic.isna().any()].index
# Out:
# Index(['age', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'], dtype='object')

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
(titanic.isna().sum()/titanic.shape[0])*100 # determine the percentage of missing values
# Out:
# pclass        0.000000
# survived      0.000000
# name          0.000000
# sex           0.000000
# age          20.091673
# sibsp         0.000000
# parch         0.000000
# ticket        0.000000
# fare          0.076394
# cabin        77.463713
# embarked      0.152788
# boat         62.872422
# body         90.756303
# home.dest    43.086325
# dtype: float64

# %%
titanic.columns [( (titanic.isna().sum()/titanic.shape[0] ) *100) <=40 ]
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'embarked'],
#       dtype='object')

# %%
titanic.loc[  :, ['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket','fare', 'embarked'] ]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
titanic.loc[  :, (titanic.isna().sum()/titanic.shape[0] ) *100 <=40 ]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
titanic.drop(columns=titanic.columns[(titanic.isna().sum()/titanic.shape[0])*100>40])
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
cars
# Out:
#       Make                     Model   Type  Origin DriveTrain   MSRP  \
# 0    Acura                       MDX    SUV    Asia        All  36945
# 1    Acura            RSX Type S 2dr  Sedan    Asia      Front  23820
# 2    Acura                   TSX 4dr  Sedan    Asia      Front  26990
# 3    Acura                    TL 4dr  Sedan    Asia      Front  33195
# 4    Acura                3.5 RL 4dr  Sedan    Asia      Front  43755
# ..     ...                       ...    ...     ...        ...    ...
# 423  Volvo   C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 424  Volvo   C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 425  Volvo                S80 T6 4dr  Sedan  Europe      Front  45210
# 426  Volvo                       V40  Wagon  Europe      Front  26135
# 427  Volvo                      XC70  Wagon  Europe        All  35145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars.sort_values(by="MSRP")
# Out:
#               Make                   Model    Type  Origin DriveTrain    MSRP  \
# 206            Kia          Rio 4dr manual   Sedan    Asia      Front   10280
# 168        Hyundai        Accent 2dr hatch   Sedan    Asia      Front   10539
# 382         Toyota         Echo 2dr manual   Sedan    Asia      Front   10760
# 345         Saturn                Ion1 4dr   Sedan     USA      Front   10995
# 207            Kia            Rio 4dr auto   Sedan    Asia      Front   11155
# ..             ...                     ...     ...     ...        ...     ...
# 261  Mercedes-Benz               CL500 2dr   Sedan  Europe       Rear   94820
# 270  Mercedes-Benz            SL55 AMG 2dr  Sports  Europe       Rear  121770
# 271  Mercedes-Benz   SL600 convertible 2dr  Sports  Europe       Rear  126670
# 262  Mercedes-Benz               CL600 2dr   Sedan  Europe       Rear  128420
# 334        Porsche             911 GT2 2dr  Sports  Europe       Rear  192465
#
# ...

# %%
cars.sort_values(by='MSRP', ascending=False)
# Out:
#               Make                   Model    Type  Origin DriveTrain    MSRP  \
# 334        Porsche             911 GT2 2dr  Sports  Europe       Rear  192465
# 262  Mercedes-Benz               CL600 2dr   Sedan  Europe       Rear  128420
# 271  Mercedes-Benz   SL600 convertible 2dr  Sports  Europe       Rear  126670
# 270  Mercedes-Benz            SL55 AMG 2dr  Sports  Europe       Rear  121770
# 261  Mercedes-Benz               CL500 2dr   Sedan  Europe       Rear   94820
# ..             ...                     ...     ...     ...        ...     ...
# 207            Kia            Rio 4dr auto   Sedan    Asia      Front   11155
# 345         Saturn                Ion1 4dr   Sedan     USA      Front   10995
# 382         Toyota         Echo 2dr manual   Sedan    Asia      Front   10760
# 168        Hyundai        Accent 2dr hatch   Sedan    Asia      Front   10539
# 206            Kia          Rio 4dr manual   Sedan    Asia      Front   10280
#
# ...

# %%
cars.groupby("Make").mean()
# Out:
#                        MSRP       Invoice  EngineSize  Cylinders  Horsepower  \
# Make
# Acura          42938.571429  38590.857143    3.042857   5.428571  239.285714
# Audi           43307.894737  39330.105263    3.057895   6.105263  250.789474
# BMW            43285.250000  39620.650000    3.125000   6.400000  241.450000
# Buick          30537.777778  27854.888889    3.722222   6.000000  214.444444
# Cadillac       50474.375000  46426.875000    4.737500   7.750000  298.125000
# Chevrolet      26587.037037  24060.814815    3.733333   6.000000  212.814815
# Chrysler       27252.000000  25270.066667    2.960000   5.333333  201.133333
# Dodge          26253.846154  24160.076923    3.484615   5.692308  209.692308
# Ford           24015.869565  21953.000000    3.552174   6.260870  197.869565
# GMC            29560.500000  26289.375000    4.650000   6.750000  253.125000
# Honda          21434.705882  19512.764706    2.382353   4.529412  169.411765
# ...

# %%
cars.groupby(["Origin", "Type","Make"])[["Weight"]].mean()
# Out:
#                              Weight
# Origin Type   Make
# Asia   Hybrid Honda     2291.000000
#               Toyota    2890.000000
#        SUV    Acura     4451.000000
#               Honda     3704.333333
#               Hyundai   3549.000000
# ...                             ...
# USA    Wagon  Chrysler  4675.000000
#               Ford      3099.500000
#               Mercury   3488.000000
#               Pontiac   2701.000000
#               Saturn    3109.000000
#
# [114 rows x 1 columns]

# %%
cars.groupby("Make").agg( ["sum", "min"] )
# Out:
#                                                            Model  \
#                                                              sum
# Make
# Acura           MDX RSX Type S 2dr TSX 4dr TL 4dr 3.5 RL 4dr ...
# Audi            A4 1.8T 4dr A41.8T convertible 2dr A4 3.0 4dr...
# BMW             X3 3.0i X5 4.4i 325i 4dr 325Ci 2dr 325Ci conv...
# Buick           Rainier Rendezvous CX Century Custom 4dr LeSa...
# Cadillac        Escalade SRX V8 CTS VVT 4dr Deville 4dr Devil...
# Chevrolet       Suburban 1500 LT Tahoe LT TrailBlazer LT Trac...
# Chrysler        PT Cruiser 4dr PT Cruiser Limited 4dr Sebring...
# Dodge           Durango SLT Neon SE 4dr Neon SXT 4dr Intrepid...
# Ford            Excursion 6.8 XLT Expedition 4.6 XLT Explorer...
# GMC             Envoy XUV SLE Yukon 1500 SLE Yukon XL 2500 SL...
# Honda           Civic Hybrid 4dr manual (gas/electric) Insigh...
# Hummer                                                        H2
# ...

# %%
cars.groupby("Make")[["MSRP", "EngineSize"]] .mean()
# Out:
#                        MSRP  EngineSize
# Make
# Acura          42938.571429    3.042857
# Audi           43307.894737    3.057895
# BMW            43285.250000    3.125000
# Buick          30537.777778    3.722222
# Cadillac       50474.375000    4.737500
# Chevrolet      26587.037037    3.733333
# Chrysler       27252.000000    2.960000
# Dodge          26253.846154    3.484615
# Ford           24015.869565    3.552174
# GMC            29560.500000    4.650000
# Honda          21434.705882    2.382353
# Hummer         49995.000000    6.000000
# Hyundai        17476.500000    2.383333
# Infiniti       36070.000000    3.875000
# Isuzu          26149.000000    3.700000
# Jaguar         61580.416667    3.858333
# Jeep           24518.333333    3.466667
# Kia            15875.909091    2.345455
# Land Rover     45831.666667    3.833333
# Lexus          44215.454545    3.718182
# Lincoln        42875.555556    4.177778
# MINI           18499.000000    1.600000
# ...

# %%
cars.groupby("Make")[["MSRP", "Horsepower"]]  .sum()
# Out:
#                   MSRP  Horsepower
# Make
# Acura           300570        1675
# Audi            822850        4765
# BMW             865705        4829
# Buick           274840        1930
# Cadillac        403795        2385
# Chevrolet       717850        5746
# Chrysler        408780        3017
# Dodge           341300        2726
# Ford            552365        4551
# GMC             236484        2025
# Honda           364390        2880
# Hummer           49995         316
# Hyundai         209718        1796
# Infiniti        288560        2330
# Isuzu            52298         468
# Jaguar          738965        3684
# Jeep             73555         535
# Kia             174635        1574
# Land Rover      137495         673
# Lexus           486370        2680
# Lincoln         385880        2343
# MINI             36998         278
# Mazda           239478        1867
# Mercedes-Benz  1577077        7246
# Mercury         251755        1896
# ...

# %%
cars.groupby('Origin').agg({'MSRP':['sum'],'Horsepower':['sum'] , 'Horsepower':['mean']})
# Out:
#            MSRP  Horsepower
#             sum        mean
# Origin
# Asia    3909129  190.702532
# Europe  5947025  251.894309
# USA     4171484  212.823129

# %%
cars.groupby('Origin').agg({'MSRP':['sum'],'Horsepower':['mean']})
# Out:
#            MSRP  Horsepower
#             sum        mean
# Origin
# Asia    3909129  190.702532
# Europe  5947025  251.894309
# USA     4171484  212.823129

# %%
cars.groupby(["Origin"]) [["Weight"]].mean()
# Out:
#              Weight
# Origin
# Asia    3319.316456
# Europe  3680.723577
# USA     3769.952381

# %%
cars.groupby('Origin')[['Type']].count()
# Out:
#         Type
# Origin
# Asia     158
# Europe   123
# USA      147

# %%
cars.groupby( ["Origin", "Type"] ) [ ["Horsepower"] ].mean()
# Out:
#                Horsepower
# Origin Type
# Asia   Hybrid   92.000000
#        SUV     214.160000
#        Sedan   181.978723
#        Sports  225.352941
#        Truck   190.250000
#        Wagon   185.636364
# Europe SUV     263.100000
#        Sedan   236.525641
#        Sports  316.739130
#        Wagon   218.166667
# USA    SUV     246.560000
#        Sedan   191.988889
#        Sports  312.000000
#        Truck   242.125000
#        Wagon   165.714286

# %%
cars.groupby (['Origin','Type']) [['Type']].count()
# Out:
#                Type
# Origin Type
# Asia   Hybrid     3
#        SUV       25
#        Sedan     94
#        Sports    17
#        Truck      8
#        Wagon     11
# Europe SUV       10
#        Sedan     78
#        Sports    23
#        Wagon     12
# USA    SUV       25
#        Sedan     90
#        Sports     9
#        Truck     16
#        Wagon      7

# %%
cars.head(3)
# Out:
#     Make            Model   Type Origin DriveTrain   MSRP  Invoice  \
# 0  Acura              MDX    SUV   Asia        All  36945    33337
# 1  Acura   RSX Type S 2dr  Sedan   Asia      Front  23820    21761
# 2  Acura          TSX 4dr  Sedan   Asia      Front  26990    24647
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183

# %%
count_cars = cars.groupby(["Origin", "Type"])[["Type"]].count()
count_cars
# Out:
#                Type
# Origin Type
# Asia   Hybrid     3
#        SUV       25
#        Sedan     94
#        Sports    17
#        Truck      8
#        Wagon     11
# Europe SUV       10
#        Sedan     78
#        Sports    23
#        Wagon     12
# USA    SUV       25
#        Sedan     90
#        Sports     9
#        Truck     16
#        Wagon      7

# %%
count_cars = count_cars.reset_index()
print(count_cars)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/62/1yjqp2vn56jdb051vqfk6y2h0000gn/T/ipykernel_2376/3985836952.py in <module>
# ----> 1 count_cars = count_cars.reset_index()
#       2 print(count_cars)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5846                     )
#    5847
# -> 5848                 new_obj.insert(0, name, level_values)
#    5849
#    5850         new_obj.index = new_index
#
# ...

# %%
count_cars.reset_index().pivot(index='Type',columns='Origin',values = 'Make')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/62/1yjqp2vn56jdb051vqfk6y2h0000gn/T/ipykernel_2376/580719466.py in <module>
# ----> 1 count_cars.reset_index().pivot(index='Type',columns='Origin',values = 'Make')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5846                     )
#    5847
# -> 5848                 new_obj.insert(0, name, level_values)
#    5849
#    5850         new_obj.index = new_index
#
# ...

# %% [markdown]
# 1. use groupby to populate average fare values for male and female, of diff pclass
# 2. chane into wide format

# %%
titanic.head(4)
# Out:
#    pclass  survived                                  name     sex      age  \
# 0       1         1         Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1         1        Allison, Master. Hudson Trevor    male   0.9167
# 2       1         0          Allison, Miss. Helen Loraine  female   2.0000
# 3       1         0  Allison, Mr. Hudson Joshua Creighton    male  30.0000
#
#    sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0      0      0   24160  211.3375       B5        S    2    NaN
# 1      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3      1      2  113781  151.5500  C22 C26        S  NaN  135.0
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON

# %%
titanic.groupby(["sex", "pclass"])[["fare"]].mean()
# Out:
#                      fare
# sex    pclass
# female 1       109.412385
#        2        23.234827
#        3        15.324250
# male   1        69.888385
#        2        19.904946
#        3        12.415462

# %%
titanic.groupby(["sex", "pclass"])[["fare"]].mean()
# Out:
#                      fare
# sex    pclass
# female 1       109.412385
#        2        23.234827
#        3        15.324250
# male   1        69.888385
#        2        19.904946
#        3        12.415462

# %%
cars.head(3)
# Out:
#     Make            Model   Type Origin DriveTrain   MSRP  Invoice  \
# 0  Acura              MDX    SUV   Asia        All  36945    33337
# 1  Acura   RSX Type S 2dr  Sedan   Asia      Front  23820    21761
# 2  Acura          TSX 4dr  Sedan   Asia      Front  26990    24647
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183

# %%
cars.head(3)
# Out:
#     Make            Model   Type Origin DriveTrain   MSRP  Invoice  \
# 0  Acura              MDX    SUV   Asia        All  36945    33337
# 1  Acura   RSX Type S 2dr  Sedan   Asia      Front  23820    21761
# 2  Acura          TSX 4dr  Sedan   Asia      Front  26990    24647
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183

# %%
cars.groupby("Origin").count()
# Out:
#         Make  Model  Type  DriveTrain  MSRP  Invoice  EngineSize  Cylinders  \
# Origin
# Asia     158    158   158         158   158      158         158        158
# Europe   123    123   123         123   123      123         123        123
# USA      147    147   147         147   147      147         147        147
#
#         Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# Origin
# Asia           158       158          158     158        158     158
# Europe         123       123          123     123        123     123
# USA            147       147          147     147        147     147

# %%
count = cars.groupby(["Origin", "Type"])[["Type"]].count()
count
# Out:
#                Type
# Origin Type
# Asia   Hybrid     3
#        SUV       25
#        Sedan     94
#        Sports    17
#        Truck      8
#        Wagon     11
# Europe SUV       10
#        Sedan     78
#        Sports    23
#        Wagon     12
# USA    SUV       25
#        Sedan     90
#        Sports     9
#        Truck     16
#        Wagon      7

# %%
count.pivot(index = "Type", columns= "Make")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/62/1yjqp2vn56jdb051vqfk6y2h0000gn/T/ipykernel_2376/2287552914.py in <module>
# ----> 1 count.pivot(index = "Type", columns= "Make")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    7883         from pandas.core.reshape.pivot import pivot
#    7884
# -> 7885         return pivot(self, index=index, columns=columns, values=values)
#    7886
#    7887     _shared_docs[
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     491         # error: Unsupported operand types for + ("List[Any]" and "ExtensionArray")
#     492         # error: Unsupported left operand type for + ("ExtensionArray")
# --> 493         indexed = data.set_index(
# ...

# %%
cars.head()
# Out:
#     Make            Model   Type Origin DriveTrain   MSRP  Invoice  \
# 0  Acura              MDX    SUV   Asia        All  36945    33337
# 1  Acura   RSX Type S 2dr  Sedan   Asia      Front  23820    21761
# 2  Acura          TSX 4dr  Sedan   Asia      Front  26990    24647
# 3  Acura           TL 4dr  Sedan   Asia      Front  33195    30299
# 4  Acura       3.5 RL 4dr  Sedan   Asia      Front  43755    39014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186
# 4        115     197

# %%
cars.isna().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
cars.loc[(cars["Cylinders"].isna()), ["Cylinders"]]
# Out:
#      Cylinders
# 247        NaN
# 248        NaN

# %%
cars["Cylinders"].value_counts()
# Out:
# 6.0     190
# 4.0     136
# 8.0      87
# 5.0       7
# 12.0      3
# 10.0      2
# 3.0       1
# Name: Cylinders, dtype: int64

# %%
cars["Cylinders"].fillna(6)
# Out:
# 0      6.0
# 1      4.0
# 2      4.0
# 3      6.0
# 4      6.0
#       ...
# 423    5.0
# 424    5.0
# 425    6.0
# 426    4.0
# 427    5.0
# Name: Cylinders, Length: 428, dtype: float64

# %%
cars["Cylinders"] = cars["Cylinders"].fillna(6)

# %%
cars.isna().any()
# Out:
# Make           False
# Model          False
# Type           False
# Origin         False
# DriveTrain     False
# MSRP           False
# Invoice        False
# EngineSize     False
# Cylinders      False
# Horsepower     False
# MPG_City       False
# MPG_Highway    False
# Weight         False
# Wheelbase      False
# Length         False
# dtype: bool

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
navalues = titanic.isna().any()

# %%
navalues[navalues].index
# Out:
# Index(['age', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'], dtype='object')

# %%
totalna = titanic.isna().sum()

# %%
(totalna/titanic.shape[0])*100
# Out:
# pclass        0.000000
# survived      0.000000
# name          0.000000
# sex           0.000000
# age          20.091673
# sibsp         0.000000
# parch         0.000000
# ticket        0.000000
# fare          0.076394
# cabin        77.463713
# embarked      0.152788
# boat         62.872422
# body         90.756303
# home.dest    43.086325
# dtype: float64

# %%
(totalna/titanic.shape[0])*100 <= 40
# Out:
# pclass        True
# survived      True
# name          True
# sex           True
# age           True
# sibsp         True
# parch         True
# ticket        True
# fare          True
# cabin        False
# embarked      True
# boat         False
# body         False
# home.dest    False
# dtype: bool

# %%
titanic.columns[ (totalna/titanic.shape[0])*100 <= 40 ]
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'embarked'],
#       dtype='object')

# %%
titanic.loc[:, [ 'pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
       'fare', 'embarked' ]]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
df = pd.DataFrame({ 'col1': [ "item1", "item2", "item3", "item4","item5"], 
                   'col2':[23,25,28,32,43],
                   'col3':[99,43,87,67,34],
                   'col4':[10,20,30,40,50]},
                   index = ['i1','i2','i3','i4','i5'])

# %%
df
# Out:
#      col1  col2  col3  col4
# i1  item1    23    99    10
# i2  item2    25    43    20
# i3  item3    28    87    30
# i4  item4    32    67    40
# i5  item5    43    34    50

# %%
df.drop(["i1","i4"], axis = 0)
# Out:
#      col1  col2  col3  col4
# i2  item2    25    43    20
# i3  item3    28    87    30
# i5  item5    43    34    50

# %%
df.drop( ["col1"], axis = 1 )
# Out:
#     col2  col3  col4
# i1    23    99    10
# i2    25    43    20
# i3    28    87    30
# i4    32    67    40
# i5    43    34    50

# %%
namorethan40 = titanic.columns[ (totalna/titanic.shape[0])*100 >= 40 ]
namorethan40
# Out:
# Index(['cabin', 'boat', 'body', 'home.dest'], dtype='object')

# %%
titanic.drop ( columns = ['cabin', 'boat', 'body', 'home.dest'] )
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
titanic.drop ( columns = titanic.columns[ (totalna/titanic.shape[0])*100 >= 40 ] )
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
df
# Out:
#      col1  col2  col3  col4
# i1  item1    23    99    10
# i2  item2    25    43    20
# i3  item3    28    87    30
# i4  item4    32    67    40
# i5  item5    43    34    50

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3', 'col4'], dtype='object')

# %%
df.columns = ['co1', 'co2', 'co3', 'co4']
df
# Out:
#       co1  co2  co3  co4
# i1  item1   23   99   10
# i2  item2   25   43   20
# i3  item3   28   87   30
# i4  item4   32   67   40
# i5  item5   43   34   50

# %%
df.index
# Out:
# Index(['i1', 'i2', 'i3', 'i4', 'i5'], dtype='object')

# %%
df.index = ['a1', 'a2', 'a3', 'a4', 'a5']
df
# Out:
#       co1  co2  co3  co4
# a1  item1   23   99   10
# a2  item2   25   43   20
# a3  item3   28   87   30
# a4  item4   32   67   40
# a5  item5   43   34   50

# %%
df.rename(columns={"co1": "va1"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/62/1yjqp2vn56jdb051vqfk6y2h0000gn/T/ipykernel_9290/2530739770.py in <module>
# ----> 1 df.rename(columns={"co1": "va1"})
#
# TypeError: 'list' object is not callable

# %%
cars.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
titanic.columns.str.replace( ".", "_" )
# Out:
# /var/folders/62/1yjqp2vn56jdb051vqfk6y2h0000gn/T/ipykernel_9290/2135685147.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   titanic.columns.str.replace( ".", "_" )
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home_dest'],
#       dtype='object')

# %%
titanic.columns = titanic.columns.str.replace( ".", "_" )
# Out:
# /var/folders/62/1yjqp2vn56jdb051vqfk6y2h0000gn/T/ipykernel_9290/4254387652.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   titanic.columns = titanic.columns.str.replace( ".", "_" )

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home_dest'],
#       dtype='object')

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
cars.sort_values(by="MSRP", ascending = False)
# Out:
#               Make                   Model    Type  Origin DriveTrain    MSRP  \
# 334        Porsche             911 GT2 2dr  Sports  Europe       Rear  192465
# 262  Mercedes-Benz               CL600 2dr   Sedan  Europe       Rear  128420
# 271  Mercedes-Benz   SL600 convertible 2dr  Sports  Europe       Rear  126670
# 270  Mercedes-Benz            SL55 AMG 2dr  Sports  Europe       Rear  121770
# 261  Mercedes-Benz               CL500 2dr   Sedan  Europe       Rear   94820
# ..             ...                     ...     ...     ...        ...     ...
# 207            Kia            Rio 4dr auto   Sedan    Asia      Front   11155
# 345         Saturn                Ion1 4dr   Sedan     USA      Front   10995
# 382         Toyota         Echo 2dr manual   Sedan    Asia      Front   10760
# 168        Hyundai        Accent 2dr hatch   Sedan    Asia      Front   10539
# 206            Kia          Rio 4dr manual   Sedan    Asia      Front   10280
#
# ...

# %%
cars.sort_values(by=["Origin", "MSRP"], ascending = [True,False])
# Out:
#           Make                    Model    Type Origin DriveTrain   MSRP  \
# 6        Acura   NSX coupe 2dr manual S  Sports   Asia       Rear  89765
# 219      Lexus                   LX 470     SUV   Asia        All  64800
# 227      Lexus   SC 430 convertible 2dr  Sports   Asia       Rear  63200
# 226      Lexus               LS 430 4dr   Sedan   Asia       Rear  55750
# 377     Toyota             Land Cruiser     SUV   Asia        All  54765
# ..         ...                      ...     ...    ...        ...    ...
# 106      Dodge              Neon SE 4dr   Sedan    USA      Front  13670
# 122       Ford      Focus ZX3 2dr hatch   Sedan    USA      Front  13270
# 68   Chevrolet        Aveo LS 4dr hatch   Sedan    USA      Front  12585
# 67   Chevrolet                 Aveo 4dr   Sedan    USA      Front  11690
# 345     Saturn                 Ion1 4dr   Sedan    USA      Front  10995
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars.groupby("Origin")[["MSRP", "Horsepower"]] .agg([ "sum", "mean"] )
# Out:
#            MSRP               Horsepower
#             sum          mean        sum        mean
# Origin
# Asia    3909129  24741.322785      30131  190.702532
# Europe  5947025  48349.796748      30983  251.894309
# USA     4171484  28377.442177      31285  212.823129

# %%
cars.groupby("Origin") .agg({ "MSRP": ["sum"], "Horsepower" : ["mean"]})
# Out:
#            MSRP  Horsepower
#             sum        mean
# Origin
# Asia    3909129  190.702532
# Europe  5947025  251.894309
# USA     4171484  212.823129

# %%
count_cars = cars.groupby(["Origin", "Type"])[["Make"]].count()
count_cars
# Out:
#                Make
# Origin Type
# Asia   Hybrid     3
#        SUV       25
#        Sedan     94
#        Sports    17
#        Truck      8
#        Wagon     11
# Europe SUV       10
#        Sedan     78
#        Sports    23
#        Wagon     12
# USA    SUV       25
#        Sedan     90
#        Sports     9
#        Truck     16
#        Wagon      7

# %%
count_cars.reset_index().pivot(index="Type", columns="Origin", values = "Make")
# Out:
# Origin  Asia  Europe   USA
# Type
# Hybrid   3.0     NaN   NaN
# SUV     25.0    10.0  25.0
# Sedan   94.0    78.0  90.0
# Sports  17.0    23.0   9.0
# Truck    8.0     NaN  16.0
# Wagon   11.0    12.0   7.0

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home_dest
# ...

# %%
avfare = titanic.groupby(["sex", "pclass"])[["fare"]].mean()
avfare
# Out:
#                      fare
# sex    pclass
# female 1       109.412385
#        2        23.234827
#        3        15.324250
# male   1        69.888385
#        2        19.904946
#        3        12.415462

# %%
avfare.reset_index()
# Out:
#       sex  pclass        fare
# 0  female       1  109.412385
# 1  female       2   23.234827
# 2  female       3   15.324250
# 3    male       1   69.888385
# 4    male       2   19.904946
# 5    male       3   12.415462

# %%
avfare.reset_index().pivot(index="sex", columns="pclass", values="fare")
# Out:
# pclass           1          2          3
# sex
# female  109.412385  23.234827  15.324250
# male     69.888385  19.904946  12.415462

# %%
avfare.reset_index().pivot(index="pclass", columns="sex", values="fare")
# Out:
# sex         female       male
# pclass
# 1       109.412385  69.888385
# 2        23.234827  19.904946
# 3        15.324250  12.415462

# %%
titanic.head(2)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.9167      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
#
#                          home_dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
titanic.pivot_table(values = "fare", index = "pclass", columns = "sex")
# Out:
# sex         female       male
# pclass
# 1       109.412385  69.888385
# 2        23.234827  19.904946
# 3        15.324250  12.415462

# %%
pd.crosstab(titanic.sex, titanic.pclass)
# Out:
# pclass    1    2    3
# sex
# female  144  106  216
# male    179  171  493

# %%
df
# Out:
#       co1  co2  co3  co4
# a1  item1   23   99   10
# a2  item2   25   43   20
# a3  item3   28   87   30
# a4  item4   32   67   40
# a5  item5   43   34   50

# %%
df["ratio"] = df.co2/df.co3

# %%
df["ratio"]
# Out:
# a1    0.232323
# a2    0.581395
# a3    0.321839
# a4    0.477612
# a5    1.264706
# Name: ratio, dtype: float64

# %%
df
# Out:
#       co1  co2  co3  co4     ratio
# a1  item1   23   99   10  0.232323
# a2  item2   25   43   20  0.581395
# a3  item3   28   87   30  0.321839
# a4  item4   32   67   40  0.477612
# a5  item5   43   34   50  1.264706

# %%
df["before_co4"] = df["co2"] + df["co3"]
df
# Out:
#       co1  co2  co3  co4     ratio  before_co4
# a1  item1   23   99   10  0.232323         122
# a2  item2   25   43   20  0.581395          68
# a3  item3   28   87   30  0.321839         115
# a4  item4   32   67   40  0.477612          99
# a5  item5   43   34   50  1.264706          77

# %%
df.insert( 4, "after.co4", (df["co2"] - df["co3"])  )

# %%
df
# Out:
#       co1  co2  co3  before.co4  after.co4  co4     ratio  before_co4
# a1  item1   23   99         122        -76   10  0.232323         122
# a2  item2   25   43          68        -18   20  0.581395          68
# a3  item3   28   87         115        -59   30  0.321839         115
# a4  item4   32   67          99        -35   40  0.477612          99
# a5  item5   43   34          77          9   50  1.264706          77

# %%
df.insert( 5, "afterafter.co4", (3)  )

# %%
df
# Out:
#       co1  co2  co3  before.co4  after.co4  afterafter.co4  co4     ratio  \
# a1  item1   23   99         122        -76               3   10  0.232323
# a2  item2   25   43          68        -18               3   20  0.581395
# a3  item3   28   87         115        -59               3   30  0.321839
# a4  item4   32   67          99        -35               3   40  0.477612
# a5  item5   43   34          77          9               3   50  1.264706
#
#     before_co4
# a1         122
# a2          68
# a3         115
# a4          99
# a5          77

# %%
titanic.head(3)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.9167      1
# 2       1         0    Allison, Miss. Helen Loraine  female   2.0000      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
# 2      2  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home_dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON

# %%
titanic["Family_size"] = titanic["sibsp"] + titanic["parch"]

# %%
titanic.head(3)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.9167      1
# 2       1         0    Allison, Miss. Helen Loraine  female   2.0000      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
# 2      2  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home_dest  Family_size
# 0                     St Louis, MO            0
# 1  Montreal, PQ / Chesterville, ON            3
# 2  Montreal, PQ / Chesterville, ON            3

# %%
titanic.insert(4, "Family_sizee", (titanic["sibsp"] + titanic["parch"]))

# %%
titanic.head(3)
# Out:
#    pclass  survived                            name     sex  Family_sizee  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female             0
# 1       1         1  Allison, Master. Hudson Trevor    male             3
# 2       1         0    Allison, Miss. Helen Loraine  female             3
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat  body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2   NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11   NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home_dest  Family_size
# 0                     St Louis, MO            0
# 1  Montreal, PQ / Chesterville, ON            3
# 2  Montreal, PQ / Chesterville, ON            3

# %%
titanic.columns.get_loc("age")
# Out:
# 5
