# %%
import pandas as pd

# %%
dr = pd.read_csv("HistoricalQuotes_Apple_TimeSeries_DateRange.csv")

# %%
dr
# Out:
#          Date    Open    High     Low   Close    Volume
# 0    1-Jun-17  153.17  153.33  152.22  153.18  16404088
# 1    2-Jun-17  153.58  155.45  152.89  155.45  27770715
# 2    5-Jun-17  154.34  154.45  153.46  153.93  25331662
# 3    6-Jun-17  153.90  155.81  153.78  154.45  26624926
# 4    7-Jun-17  155.02  155.98  154.48  155.37  21069647
# 5    8-Jun-17  155.25  155.54  154.40  154.99  21250798
# 6    9-Jun-17  155.19  155.19  146.02  148.98  64882657
# 7   12-Jun-17  145.74  146.09  142.51  145.42  72307330
# 8   13-Jun-17  147.16  147.45  145.15  146.59  34165445
# 9   14-Jun-17  147.50  147.50  143.84  145.16  31531232
# 10  15-Jun-17  143.32  144.48  142.21  144.29  32165373
# 11  16-Jun-17  143.78  144.50  142.20  142.27  50361093
# 12  19-Jun-17  143.66  146.74  143.66  146.34  32541404
# 13  20-Jun-17  146.87  146.87  144.94  145.01  24900073
# 14  21-Jun-17  145.52  146.07  144.61  145.87  21265751
# 15  22-Jun-17  145.77  146.70  145.12  145.63  19106294
# ...

# %%
dr.head()
# Out:
#        Date    Open    High     Low   Close    Volume
# 0  1-Jun-17  153.17  153.33  152.22  153.18  16404088
# 1  2-Jun-17  153.58  155.45  152.89  155.45  27770715
# 2  5-Jun-17  154.34  154.45  153.46  153.93  25331662
# 3  6-Jun-17  153.90  155.81  153.78  154.45  26624926
# 4  7-Jun-17  155.02  155.98  154.48  155.37  21069647

# %%
nd = pd.read_csv("HistoricalQuotes_Apple_TimeSeries_DateRange_NoDates.csv")
nd
# Out:
#       Open    High     Low   Close    Volume
# 0   153.17  153.33  152.22  153.18  16404088
# 1   153.58  155.45  152.89  155.45  27770715
# 2   154.34  154.45  153.46  153.93  25331662
# 3   153.90  155.81  153.78  154.45  26624926
# 4   155.02  155.98  154.48  155.37  21069647
# 5   155.25  155.54  154.40  154.99  21250798
# 6   155.19  155.19  146.02  148.98  64882657
# 7   145.74  146.09  142.51  145.42  72307330
# 8   147.16  147.45  145.15  146.59  34165445
# 9   147.50  147.50  143.84  145.16  31531232
# 10  143.32  144.48  142.21  144.29  32165373
# 11  143.78  144.50  142.20  142.27  50361093
# 12  143.66  146.74  143.66  146.34  32541404
# 13  146.87  146.87  144.94  145.01  24900073
# 14  145.52  146.07  144.61  145.87  21265751
# 15  145.77  146.70  145.12  145.63  19106294
# 16  145.13  147.16  145.11  146.28  35439389
# 17  147.17  148.28  145.38  145.82  25692361
# 18  145.01  146.16  143.62  143.73  24761891
# 19  144.49  146.11  143.16  145.83  22082432
# ...

# %%
print(nd["2017-06-01":"2017-06-10"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/62/1yjqp2vn56jdb051vqfk6y2h0000gn/T/ipykernel_12282/885059112.py in <module>
# ----> 1 print(nd["2017-06-01":"2017-06-10"])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3475
#    3476         # Do we have a slicer (on rows)?
# -> 3477         indexer = convert_to_index_sliceable(self, key)
#    3478         if indexer is not None:
#    3479             if isinstance(indexer, np.ndarray):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in convert_to_index_sliceable(obj, key)
#    2327     idx = obj.index
#    2328     if isinstance(key, slice):
# -> 2329         return idx._convert_slice_indexer(key, kind="getitem")
#    2330
#    2331     elif isinstance(key, str):
#
# ...

# %%
df.head(3)
# Out:
#        Date    Open    High     Low   Close    Volume
# 0  1-Jun-17  153.17  153.33  152.22  153.18  16404088
# 1  2-Jun-17  153.58  155.45  152.89  155.45  27770715
# 2  5-Jun-17  154.34  154.45  153.46  153.93  25331662

# %%
url = "https://bit.ly/uforeports"
ufo = pd.read_csv(url)

# %%
ufo.head(4)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3      Abilene             NaN           DISK    KS   6/1/1931 13:00

# %%
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
import numpy as np

# %%
ufo["Time"] = pd.to_datetime(ufo.Time)
ufo.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# dtype: object

# %%
ufo.Time.dt.hour
# Out:
# 0        22
# 1        20
# 2        14
# 3        13
# 4        19
#          ..
# 18236    23
# 18237    23
# 18238    23
# 18239    23
# 18240    23
# Name: Time, Length: 18241, dtype: int64

# %%
ufo.Time.max(), ufo.Time.min()
# Out:
# (Timestamp('2000-12-31 23:59:00'), Timestamp('1930-06-01 22:00:00'))

# %%
ufo.Time.max() - ufo.Time.min()
# Out:
# Timedelta('25781 days 01:59:00')

# %%
ufo["Year"] = ufo.Time.dt.year
ufo["Month"] = ufo.Time.dt.month

# %%
ufo.head(3)
# Out:
#           City Colors Reported Shape Reported State                Time  Year  \
# 0       Ithaca             NaN       TRIANGLE    NY 1930-06-01 22:00:00  1930
# 1  Willingboro             NaN          OTHER    NJ 1930-06-30 20:00:00  1930
# 2      Holyoke             NaN           OVAL    CO 1931-02-15 14:00:00  1931
#
#    Month
# 0      6
# 1      6
# 2      2

# %%
nd.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  153.17  153.33  152.22  153.18  16404088
# 1  153.58  155.45  152.89  155.45  27770715
# 2  154.34  154.45  153.46  153.93  25331662
# 3  153.90  155.81  153.78  154.45  26624926
# 4  155.02  155.98  154.48  155.37  21069647

# %%
junrng = pd.date_range(start = "6/1/2017", end= "6/30/2017", freq= "B")

# %%
nd.set_index(junrng, inplace = True)

# %%
nd.head()
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647

# %%
nd["6/1/2017": "6/10/2017"].Close.mean()
# Out:
# 153.7642857142857

# %%
print(nd["6/1/2017": "6/10/2017"])
print("-"*55)
print("The mean of the close of 10 days is {} ".format( nd["6/1/2017": "6/10/2017"].Close.mean()))
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# -------------------------------------------------------
# The mean of the close of 10 days is 153.7642857142857

# %%
nd.asfreq("D", method = "pad")
nd.asfreq("H", method = "pad")
# Out:
#                        Open    High     Low   Close    Volume
# 2017-06-01 00:00:00  153.17  153.33  152.22  153.18  16404088
# 2017-06-01 01:00:00  153.17  153.33  152.22  153.18  16404088
# 2017-06-01 02:00:00  153.17  153.33  152.22  153.18  16404088
# 2017-06-01 03:00:00  153.17  153.33  152.22  153.18  16404088
# 2017-06-01 04:00:00  153.17  153.33  152.22  153.18  16404088
# ...                     ...     ...     ...     ...       ...
# 2017-06-29 20:00:00  144.71  145.13  142.28  143.68  31499368
# 2017-06-29 21:00:00  144.71  145.13  142.28  143.68  31499368
# 2017-06-29 22:00:00  144.71  145.13  142.28  143.68  31499368
# 2017-06-29 23:00:00  144.71  145.13  142.28  143.68  31499368
# 2017-06-30 00:00:00  144.45  144.96  143.78  144.02  23024107
#
# [697 rows x 5 columns]

# %%
pd.date_range(start="1/1/2017", periods=72, freq="B")
# Out:
# DatetimeIndex(['2017-01-02', '2017-01-03', '2017-01-04', '2017-01-05',
#                '2017-01-06', '2017-01-09', '2017-01-10', '2017-01-11',
#                '2017-01-12', '2017-01-13', '2017-01-16', '2017-01-17',
#                '2017-01-18', '2017-01-19', '2017-01-20', '2017-01-23',
#                '2017-01-24', '2017-01-25', '2017-01-26', '2017-01-27',
#                '2017-01-30', '2017-01-31', '2017-02-01', '2017-02-02',
#                '2017-02-03', '2017-02-06', '2017-02-07', '2017-02-08',
#                '2017-02-09', '2017-02-10', '2017-02-13', '2017-02-14',
#                '2017-02-15', '2017-02-16', '2017-02-17', '2017-02-20',
#                '2017-02-21', '2017-02-22', '2017-02-23', '2017-02-24',
#                '2017-02-27', '2017-02-28', '2017-03-01', '2017-03-02',
#                '2017-03-03', '2017-03-06', '2017-03-07', '2017-03-08',
#                '2017-03-09', '2017-03-10', '2017-03-13', '2017-03-14',
# ...

# %%
dr.head()
# Out:
#        Date    Open    High     Low   Close    Volume
# 0  1-Jun-17  153.17  153.33  152.22  153.18  16404088
# 1  2-Jun-17  153.58  155.45  152.89  155.45  27770715
# 2  5-Jun-17  154.34  154.45  153.46  153.93  25331662
# 3  6-Jun-17  153.90  155.81  153.78  154.45  26624926
# 4  7-Jun-17  155.02  155.98  154.48  155.37  21069647

# %%
dr["Date Converted"] = pd.to_datetime(dr["Date"])

# %%
dr["Day Week"] = dr["Date Converted"].dt.dayofweek
dr
# Out:
#          Date    Open    High     Low   Close    Volume Date Converted  \
# 0    1-Jun-17  153.17  153.33  152.22  153.18  16404088     2017-06-01
# 1    2-Jun-17  153.58  155.45  152.89  155.45  27770715     2017-06-02
# 2    5-Jun-17  154.34  154.45  153.46  153.93  25331662     2017-06-05
# 3    6-Jun-17  153.90  155.81  153.78  154.45  26624926     2017-06-06
# 4    7-Jun-17  155.02  155.98  154.48  155.37  21069647     2017-06-07
# 5    8-Jun-17  155.25  155.54  154.40  154.99  21250798     2017-06-08
# 6    9-Jun-17  155.19  155.19  146.02  148.98  64882657     2017-06-09
# 7   12-Jun-17  145.74  146.09  142.51  145.42  72307330     2017-06-12
# 8   13-Jun-17  147.16  147.45  145.15  146.59  34165445     2017-06-13
# 9   14-Jun-17  147.50  147.50  143.84  145.16  31531232     2017-06-14
# 10  15-Jun-17  143.32  144.48  142.21  144.29  32165373     2017-06-15
# 11  16-Jun-17  143.78  144.50  142.20  142.27  50361093     2017-06-16
# ...

# %%
import pytz

for timezone in pytz.common_timezones:
    print(timezone)
# Out:
# Africa/Abidjan
# Africa/Accra
# Africa/Addis_Ababa
# Africa/Algiers
# Africa/Asmara
# Africa/Bamako
# Africa/Bangui
# Africa/Banjul
# Africa/Bissau
# Africa/Blantyre
# Africa/Brazzaville
# Africa/Bujumbura
# Africa/Cairo
# Africa/Casablanca
# Africa/Ceuta
# Africa/Conakry
# Africa/Dakar
# Africa/Dar_es_Salaam
# Africa/Djibouti
# Africa/Douala
# Africa/El_Aaiun
# Africa/Freetown
# Africa/Gaborone
# Africa/Harare
# Africa/Johannesburg
# Africa/Juba
# Africa/Kampala
# Africa/Khartoum
# Africa/Kigali
# Africa/Kinshasa
# Africa/Lagos
# Africa/Libreville
# Africa/Lome
# Africa/Luanda
# Africa/Lubumbashi
# Africa/Lusaka
# Africa/Malabo
# Africa/Maputo
# Africa/Maseru
# Africa/Mbabane
# Africa/Mogadishu
# Africa/Monrovia
# Africa/Nairobi
# Africa/Ndjamena
# Africa/Niamey
# Africa/Nouakchott
# Africa/Ouagadougou
# Africa/Porto-Novo
# Africa/Sao_Tome
# Africa/Tripoli
# Africa/Tunis
# Africa/Windhoek
# America/Adak
# America/Anchorage
# America/Anguilla
# America/Antigua
# America/Araguaina
# ...

# %%
sunday_hols = []

for date in dates:
    if date.weekday == 6:
        sunday_hols.append(date)
        
        
monday_off = []

for date in sunday_hols:
    monday_off.append(date + timedelta(days=1))
